# %% [markdown]
# # Question 1
# Write a decorator function for your taking input for you any kind of function you want to build,
# For example - You make a fibonacci series function,in which your input range is been defined by
# the decorator program input.

# %%
import collections
import functools


def memoize(function):
    cache = {}

    @functools.wraps(function)
    def wrap(*args, **kwargs):
        if not isinstance(args, collections.Hashable):
            return function(*args, **kwargs)

        if args in cache:
            print('returning fib({}) from cache.'.format(*args))
            return cache[args]

        print('calling fib({})'.format(*args))
        value = function(*args, **kwargs)

        print('adding fib({}) to cache'.format(*args))
        cache[args] = value

        return value

    return wrap


@memoize
def fib(n):
    """
    Returns the n'th Fibonacci number where n is an integer >= 0
    :param n: integer >= 0
    :return: n'th Fibonacci number
    """
    if n < 2:
        return n

    return fib(n - 1) + fib(n - 2)


for i in range(20):
    print(fib(i), end='\n\n')
# Out:
# calling fib(0)
# adding fib(0) to cache
# 0
#
# calling fib(1)
# adding fib(1) to cache
# 1
#
# calling fib(2)
# returning fib(1) from cache.
# returning fib(0) from cache.
# adding fib(2) to cache
# 1
#
# calling fib(3)
# returning fib(2) from cache.
# returning fib(1) from cache.
# adding fib(3) to cache
# 2
#
# calling fib(4)
# returning fib(3) from cache.
# returning fib(2) from cache.
# adding fib(4) to cache
# 3
#
# calling fib(5)
# returning fib(4) from cache.
# returning fib(3) from cache.
# adding fib(5) to cache
# 5
#
# calling fib(6)
# returning fib(5) from cache.
# returning fib(4) from cache.
# adding fib(6) to cache
# 8
#
# calling fib(7)
# returning fib(6) from cache.
# returning fib(5) from cache.
# adding fib(7) to cache
# 13
#
# calling fib(8)
# returning fib(7) from cache.
# returning fib(6) from cache.
# adding fib(8) to cache
# 21
#
# calling fib(9)
# returning fib(8) from cache.
# returning fib(7) from cache.
# adding fib(9) to cache
# 34
#
# calling fib(10)
# returning fib(9) from cache.
# returning fib(8) from cache.
# adding fib(10) to cache
# 55
#
# calling fib(11)
# returning fib(10) from cache.
# returning fib(9) from cache.
# adding fib(11) to cache
# 89
#
# calling fib(12)
# returning fib(11) from cache.
# returning fib(10) from cache.
# adding fib(12) to cache
# 144
#
# calling fib(13)
# returning fib(12) from cache.
# returning fib(11) from cache.
# adding fib(13) to cache
# 233
#
# calling fib(14)
# returning fib(13) from cache.
# returning fib(12) from cache.
# adding fib(14) to cache
# 377
#
# calling fib(15)
# returning fib(14) from cache.
# returning fib(13) from cache.
# adding fib(15) to cache
# 610
#
# calling fib(16)
# returning fib(15) from cache.
# returning fib(14) from cache.
# adding fib(16) to cache
# 987
#
# calling fib(17)
# returning fib(16) from cache.
# returning fib(15) from cache.
# adding fib(17) to cache
# 1597
#
# calling fib(18)
# returning fib(17) from cache.
# returning fib(16) from cache.
# adding fib(18) to cache
# 2584
#
# calling fib(19)
# returning fib(18) from cache.
# returning fib(17) from cache.
# adding fib(19) to cache
# 4181
# <ipython-input-1-b82fb4894246>:10: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   if not isinstance(args, collections.Hashable):

# %% [markdown]
# # For this challenge you need to develop a Python program to open a file in read only mode and try
# writing something to it and handle the subsequent errors using Exception Handling

# %%
try:
    f = open('letsupdrade.txt', 'r')
    print(f.read())
    f.close()
except IOError:
    print('file not found')
    
except UnicodeDecodeError :
    print("file not found")
# Out:
# file not found
